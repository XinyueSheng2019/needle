# %%
from image_preprocessing import *

obj_A = 'ZTF18aavrmcg'
image_demo = ImagePreprocessing(ztf_object = obj_A, 
                                output_path = '../plots/plot_images',
                                display = True, train_mode = False)
img_data = image_demo.img_data
# Out:
# image preprocessing ztf_object:  ZTF18aavrmcg
# Loaded image data for ZTF18aavrmcg

# %%
import matplotlib.pyplot as plt
plt.imshow(img_data[0])
plt.show()
